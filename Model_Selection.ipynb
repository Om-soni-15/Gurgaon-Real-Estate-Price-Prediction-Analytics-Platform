# %% [markdown]
# <a href="https://colab.research.google.com/github/Om-soni-15/Gurgaon-Real-Estate-Price-Prediction-Analytics-Platform/blob/master/Model_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### comment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/Gurgaon_properties_post_feature_selection_V2.csv')

# %%
df.head()
# Out:
#   property_type     sector  price  bedRoom  bathroom  balcony      facing  \
# 0         house  sector 70   5.25      2.0         4        4  North-East
# 1         house  sector 43   2.10      2.0        10        4        West
# 2         house  sector 54   5.00      4.0        21        4       North
# 3         house  sector 43   3.00      2.0        12        4        West
# 4         house  sector 43   4.50      5.0        20        4        East
#
#     agePossession  Built_up_area  servant room  store room furnishing_type  \
# 0    New Property         2609.0             1           0     unfurnished
# 1    New Property          549.0             1           0     unfurnished
# 2  Relatively New         1161.0             1           0   semifurnished
# 3    New Property          558.0             0           0   semifurnished
# 4  Relatively New         1152.0             1           0   semifurnished
#
#   facilities floor_category
# 0   standard      Mid Floor
# ...

# %%
df['servant room']=df['servant room'].replace(0,'No')
df['servant room']=df['servant room'].replace(1,'Yes')
df.head()
# Out:
#   property_type     sector  price  bedRoom  bathroom  balcony      facing  \
# 0         house  sector 70   5.25      2.0         4        4  North-East
# 1         house  sector 43   2.10      2.0        10        4        West
# 2         house  sector 54   5.00      4.0        21        4       North
# 3         house  sector 43   3.00      2.0        12        4        West
# 4         house  sector 43   4.50      5.0        20        4        East
#
#     agePossession  Built_up_area servant room  store room furnishing_type  \
# 0    New Property         2609.0          Yes           0     unfurnished
# 1    New Property          549.0          Yes           0     unfurnished
# 2  Relatively New         1161.0          Yes           0   semifurnished
# 3    New Property          558.0           No           0   semifurnished
# 4  Relatively New         1152.0          Yes           0   semifurnished
#
#   facilities floor_category
# 0   standard      Mid Floor
# ...

# %%
df['store room']=df['store room'].replace(0,'No')
df['store room']=df['store room'].replace(1,'Yes')
df.head()
# Out:
#   property_type     sector  price  bedRoom  bathroom  balcony      facing  \
# 0         house  sector 70   5.25      2.0         4        4  North-East
# 1         house  sector 43   2.10      2.0        10        4        West
# 2         house  sector 54   5.00      4.0        21        4       North
# 3         house  sector 43   3.00      2.0        12        4        West
# 4         house  sector 43   4.50      5.0        20        4        East
#
#     agePossession  Built_up_area servant room store room furnishing_type  \
# 0    New Property         2609.0          Yes         No     unfurnished
# 1    New Property          549.0          Yes         No     unfurnished
# 2  Relatively New         1161.0          Yes         No   semifurnished
# 3    New Property          558.0           No         No   semifurnished
# 4  Relatively New         1152.0          Yes         No   semifurnished
#
#   facilities floor_category
# 0   standard      Mid Floor
# ...

# %%
#num --> price,Built_up_area,bedRoom,bathroom,balcony  -- > aply scaling
# cat --> property_type, sector,facing,agePossession,servent room,store romm,furnishing_type,facilities,floor_category
# cols to ohe --> sector,facing,agePossession,furnishing_type,facilities,floor_category
# cols to ordinal encoding -->property_type,servent room,store romm,

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
y_transformed = np.log1p(y)

# %%
df.isnull().sum()
# Out:
# property_type      0
# sector             0
# price              0
# bedRoom            0
# bathroom           0
# balcony            0
# facing             0
# agePossession      0
# Built_up_area      0
# servant room       0
# store room         0
# furnishing_type    0
# facilities         0
# floor_category     0
# dtype: int64

# %%
df[df['floor_category'].isnull()]
# Out:
# Empty DataFrame
# Columns: [property_type, sector, price, bedRoom, bathroom, balcony, facing, agePossession, Built_up_area, servant room, store room, furnishing_type, facilities, floor_category]
# Index: []

# %%
df.sector.value_counts()
# Out:
# sector
# sohna road         163
# sector 37          115
# sector 85          108
# sector 102         107
# sector 70          102
#                   ...
# mehrauli gurgao      4
# sector 1             4
# sector 8             3
# sector 27            3
# maruti kunj          2
# Name: count, Length: 100, dtype: int64

# %%
df.to_csv('Gurgaon_properties_post_feature_selection_V3.csv',index=False)

# %% [markdown]
# ### Code to Run

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df=pd.read_csv('/content/Gurgaon_properties_post_feature_selection_V3.csv')

# %%
df.head()
# Out:
#   property_type     sector  price  bedRoom  bathroom  balcony      facing  \
# 0         house  sector 70   5.25      2.0         4        4  North-East
# 1         house  sector 43   2.10      2.0        10        4        West
# 2         house  sector 54   5.00      4.0        21        4       North
# 3         house  sector 43   3.00      2.0        12        4        West
# 4         house  sector 43   4.50      5.0        20        4        East
#
#     agePossession  Built_up_area servant room store room furnishing_type  \
# 0    New Property         2609.0          Yes         No     unfurnished
# 1    New Property          549.0          Yes         No     unfurnished
# 2  Relatively New         1161.0          Yes         No   semifurnished
# 3    New Property          558.0           No         No   semifurnished
# 4  Relatively New         1152.0          Yes         No   semifurnished
#
#   facilities floor_category
# 0   standard      Mid Floor
# ...

# %%
df.isnull().sum()
# Out:
# property_type      0
# sector             0
# price              0
# bedRoom            0
# bathroom           0
# balcony            0
# facing             0
# agePossession      0
# Built_up_area      0
# servant room       0
# store room         0
# furnishing_type    0
# facilities         0
# floor_category     0
# dtype: int64

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
y_transformed = np.log1p(y)

# %%
df.dtypes
# Out:
# property_type       object
# sector              object
# price              float64
# bedRoom            float64
# bathroom             int64
# balcony              int64
# facing              object
# agePossession       object
# Built_up_area      float64
# servant room        object
# store room          object
# furnishing_type     object
# facilities          object
# floor_category      object
# dtype: object

# %% [markdown]
# ## ordinal encoding

# %%
columns_to_encode = ['property_type','sector', 'agePossession','facing', 'furnishing_type', 'facilities', 'floor_category', 'servant room', 'store room']

# %%
preprocessor = ColumnTransformer(
     transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'balcony','Built_up_area']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2', error_score='raise')

# %%
scores.mean()
# Out:
# np.float64(0.713049890195712)

# %% [markdown]
# ## One hot encoding

# %%
#num --> price,Built_up_area,bedRoom,bathroom,balcony  -- > aply scaling
# cat --> property_type, sector,facing,agePossession,servent room,store romm,furnishing_type,facilities,floor_category
# cols to ohe --> sector,facing,agePossession,furnishing_type,facilities,floor_category
# cols to ordinal encoding -->property_type,servent room,store romm,

# %%
columns_to_encode = ['property_type','servant room', 'store room']

# %%
preprocessor = ColumnTransformer(
     transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'Built_up_area','balcony']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1', OneHotEncoder(handle_unknown='ignore',drop='first'), ['sector','agePossession', 'furnishing_type','facing', 'facilities', 'floor_category'])
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2', error_score='raise')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# np.float64(0.8395747596887706)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'Built_up_area',
#                                                    'balcony']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'agePossession', 'facing',
#                                                    'furnishing_type',
#                                                    'facilities',
# ...

# %%
y_pred = pipeline.predict(X_test)
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.7332934415183517

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...

# %%
model_output
# Out:
# [['linear_reg', np.float64(0.8395747596887706), 0.7332934415183517],
#  ['svr', np.float64(0.7523201394241789), 1.0235821672669014],
#  ['ridge', np.float64(0.8381745442011598), 0.7431628758902714],
#  ['LASSO', np.float64(0.04860740705624135), 1.7320281438775096],
#  ['decision tree', np.float64(0.8041347528569034), 0.8296047525226314],
#  ['random forest', np.float64(0.8887003252613942), 0.6335818077710639],
#  ['extra trees', np.float64(0.8914721413271025), 0.6287220954262168],
#  ['gradient boosting', np.float64(0.8802391100817777), 0.6686572281309585],
#  ['adaboost', np.float64(0.7439399750555821), 0.988261017632524],
#  ['mlp', np.float64(0.8625279412996439), 0.6899798746733361],
#  ['xgboost', np.float64(0.897117092124262), 0.6008563534461377]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.897117  0.600856
# 6         extra trees  0.891472  0.628722
# 5       random forest  0.888700  0.633582
# 7   gradient boosting  0.880239  0.668657
# 9                 mlp  0.862528  0.689980
# 0          linear_reg  0.839575  0.733293
# 2               ridge  0.838175  0.743163
# 4       decision tree  0.804135  0.829605
# 8            adaboost  0.743940  0.988261
# 1                 svr  0.752320  1.023582
# 3               LASSO  0.048607  1.732028

# %% [markdown]
# ## Total Encoding

# %%
! pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 7.7 MB/s eta 0:00:00
# ...

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
y_transformed = np.log1p(y)

# %%
x_ = X.drop(columns=['facing'])

# %%
X.sector.value_counts()
# Out:
# sector
# sohna road         163
# sector 37          115
# sector 85          108
# sector 102         107
# sector 70          102
#                   ...
# sector 1             4
# mehrauli gurgao      4
# sector 8             3
# sector 27            3
# maruti kunj          2
# Name: count, Length: 100, dtype: int64

# %%
df.drop(index=[128,290,374],inplace=True)

# %%
X[X['sector'] == 'sector 8']
# Out:
# Empty DataFrame
# Columns: [property_type, sector, bedRoom, bathroom, balcony, facing, agePossession, Built_up_area, servant room, store room, furnishing_type, facilities, floor_category]
# Index: []

# %%
import category_encoders as ce

columns_to_encode = ['property_type', 'servant room', 'facing','store room', 'balcony']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'Built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore'),['agePossession','furnishing_type', 'facilities', 'floor_category']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(
        colsample_bytree=0.6,
        gamma=0,
        learning_rate=0.2,
        max_depth=5,
        n_estimators=500,
        reg_lambda=1.5,
        subsample=1.0,
        random_state=42  # Ensuring reproducibility
    ))
])

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(
    subsample=1.0,
    reg_lambda=1.0,
    n_estimators=800,
    max_depth=6,
    learning_rate=0.1,
    gamma=0,
    colsample_bytree=0.8,
    random_state=42  # Ensuring reproducibility
))
])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GroupKFold

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2',error_score='raise')

# %%
scores.mean()
# Out:
# np.float64(0.9042740391582174)

# %%
target_encoder = ce.TargetEncoder(cols=['sector'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

pipeline.fit(X_train,y_train)
# X_test['sector'] = target_encoder.transform(X_test['sector'])
y_pred = pipeline.predict(X_test)

y_pred = np.expm1(y_pred)

(mean_absolute_error(np.expm1(y_test),y_pred))
# Out:
# 0.4916862445711578

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
model_dict = {
    # 'linear_reg':LinearRegression(),
    # 'svr':SVR(),
    # 'ridge':Ridge(),
    # 'LASSO':Lasso(),
    # 'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    # 'gradient boosting': GradientBoostingRegressor(),
    # 'adaboost': AdaBoostRegressor(),
    # 'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])
model_df.sort_values(['mae'])
# Out:
#             name        r2       mae
# 0  random forest  0.894530  0.596298
# 2        xgboost  0.896065  0.601824
# 1    extra trees  0.887496  0.628488

# %% [markdown]
# ## Hyperparameter tunning

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
import category_encoders as ce

columns_to_encode = ['property_type','sector','facing' ,'agePossession', 'furnishing_type', 'facilities', 'floor_category', 'servant room', 'store room']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'Built_up_area', 'balcony']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'),['agePossession','furnishing_type', 'facilities', 'floor_category']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# %%
param_grid = {
    'regressor__n_estimators': [100, 300, 500, 700],
    'regressor__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'regressor__max_depth': [3, 5, 7, 10],
    'regressor__subsample': [0.6, 0.8, 1.0],
    'regressor__colsample_bytree': [0.6, 0.8, 1.0],
    'regressor__gamma': [0, 0.1, 0.2, 0.5],
    'regressor__reg_lambda': [0, 0.1, 0.5, 1.0],
}


kfold = KFold(n_splits=10, shuffle=True, random_state=42)

random_search = RandomizedSearchCV(pipeline,param_distributions=param_grid, n_iter=20,scoring='r2',cv=kfold,verbose=4, n_jobs=-1)

random_search.fit(X, y_transformed)
print("Best Parameters (RandomizedSearchCV):", random_search.best_params_)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Best Parameters (RandomizedSearchCV): {'regressor__subsample': 1.0, 'regressor__reg_lambda': 1.0, 'regressor__n_estimators': 700, 'regressor__max_depth': 5, 'regressor__learning_rate': 0.05, 'regressor__gamma': 0, 'regressor__colsample_bytree': 1.0}

# %%
pipe=random_search.best_estimator_

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

y_pred = np.expm1(y_pred)

print(mean_absolute_error(np.expm1(y_test),y_pred))
# Out:
# 0.512306217228053

# %%
random_search.best_score_
# Out:
# np.float64(nan)

# %% [markdown]
# GridSearchCV

# %%
from sklearn.metrics import r2_score
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(eval_metric='rmse', objective='reg:squarederror'))
])
param_grid = {
    'regressor__n_estimators': [100, 300, 500, 700],
    'regressor__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'regressor__max_depth': [3, 5, 7, 10],
    'regressor__subsample': [0.6, 0.8, 1.0],
    'regressor__colsample_bytree': [0.6, 0.8, 1.0],
    'regressor__gamma': [0, 0.1, 0.2, 0.5],
    'regressor__reg_lambda': [0, 0.1, 0.5, 1.0],
}

# K-Fold Cross Validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# Hyperparameter Tuning using GridSearchCV
grid_search = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    scoring='r2',
    cv=kfold,
    verbose=2,
    n_jobs=-1  # Use all CPU cores
)

# Fit the Model
grid_search.fit(X, y_transformed)

# Print Best Parameters
print("Best Parameters (GridSearchCV):", grid_search.best_params_)

# Best Model
best_model = grid_search.best_estimator_

# # Predict on Test Data (if needed)
# y_pred = best_model.predict(X_test)
# print("Best Model R2 Score:", r2_score(np.expm1(y_test), y_pred))
# Out:
# Fitting 10 folds for each of 9216 candidates, totalling 92160 fits

# %%
grid_search.best_score_

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor())
])

# %%
param_grid = {
    'regressor__n_estimators': [500, 700, 900],  # Number of boosting rounds
    'regressor__learning_rate': [0.1, 0.2, 0.3],  # Learning rate
    'regressor__max_depth': [5, 6, 7],  # Depth of each tree
    'regressor__subsample': [0.8, 1.0],  # Percentage of samples used per tree
    'regressor__colsample_bytree': [0.6, 0.7, 0.8],  # Percentage of features used per tree
    'regressor__gamma': [0, 0.1, 0.2],  # Minimum loss reduction for further partitioning
    'regressor__reg_lambda': [0.5, 1.0, 1.5]  # L2 Regularization
}
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
# Define GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',  # Minimize MAE
    cv=5,  # 5-fold cross-validation
    verbose=2,
    n_jobs=-1  # Use all CPU cores
)

# Fit GridSearchCV
grid_search.fit(X, y_transformed)

# Best Parameters & Score
print("Best Parameters:", grid_search.best_params_)
print("Best MAE Score:", -grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 1458 candidates, totalling 7290 fits
# Best Parameters: {'regressor__colsample_bytree': 0.6, 'regressor__gamma': 0, 'regressor__learning_rate': 0.2, 'regressor__max_depth': 5, 'regressor__n_estimators': 500, 'regressor__reg_lambda': 1.5, 'regressor__subsample': 1.0}
# Best MAE Score: 0.15554911812788105

# %%
# numeric_features = ['bedRoom', 'bathroom', 'Built_up_area', 'balcony']
# numeric_transformer = StandardScaler()


# # columns_to_encode = ['property_type', 'facing', 'agePossession',
# #                     'furnishing_type', 'facilities', 'floor_category',
# #                     'servant room', 'store room']

# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', numeric_transformer, numeric_features),
#         ('cat', OrdinalEncoder(), columns_to_encode)
#     ], remainder='passthrough'  # Keep target-encoded categorical features
# )

# %%
from xgboost import XGBRegressor

# %%
from sklearn.preprocessing import FunctionTransformer
log_transformer = FunctionTransformer(np.log1p, inverse_func=np.expm1, validate=True)

# %%
from sklearn.compose import TransformedTargetRegressor
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', TransformedTargetRegressor(
        regressor=XGBRegressor(
            subsample=0.8,
            reg_lambda=1.0,
            n_estimators=700,
            max_depth=5,
            learning_rate=0.1,
            gamma=0,
            colsample_bytree=0.8,
            random_state=42  # Ensuring reproducibility
        ),
        transformer=log_transformer  # Apply log transformation to y
    ))
])

# %%
from sklearn.compose import TransformedTargetRegressor
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', TransformedTargetRegressor(
        regressor=XGBRegressor(
            colsample_bytree=0.6,
            gamma=0,
            learning_rate=0.2,
            max_depth=5,
            n_estimators=500,
            reg_lambda=1.5,
            subsample=1.0,
            random_state=42
        ),
        transformer=log_transformer  # Apply log transformation to y
    ))
])

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', TransformedTargetRegressor(
    regressor=XGBRegressor(
    n_estimators=900,
    learning_rate=0.2,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.6,
    reg_lambda=0.5,
    gamma=0,
    random_state=42
    ),
    transformer=log_transformer
  ))
])

# %%
from sklearn.metrics import make_scorer, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold
mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)
# cv_scores = cross_val_score(pipeline, X_encoded, y_transformed, cv=kfold, scoring=mae_scorer, error_score='raise')

# # Print MAE
# print(f"Cross-validated MAE: {-np.mean(cv_scores)}")

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y, cv=kfold, scoring=mae_scorer,error_score='raise')

# %%
print(f"Cross-validated MAE: {-np.mean(scores)}")
# Out:
# Cross-validated MAE: 0.48753727813444314
